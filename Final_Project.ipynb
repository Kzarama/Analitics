# %% [markdown]
# # PROYECTO FINAL ANALÍTICA DE DATOS
#
# El dataset que se va a analizar contiene las estadísticas avanzadas de rendimiento de jugadores de baloncesto en la NBA durante la temporada 2017-2018, así como los salarios de los mismos.
#
# La idea es poder predecir los salarios a partir de un modelo basado en los demás campos.
#
# **Integrantes:**
#
# - Cristian Castillo
# - Kevin Zarama
# - Jorge Morale

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
salaries = pd.read_csv('2017-18_NBA_salary.csv')
df = pd.DataFrame(salaries)
df
# Out:
#              Player    Salary       NBA_Country  NBA_DraftNumber  Age   Tm  \
# 0           Zhou Qi    815615             China               43   22  HOU
# 1     Zaza Pachulia   3477600           Georgia               42   33  GSW
# 2     Zach Randolph  12307692               USA               19   36  SAC
# 3       Zach LaVine   3202217               USA               13   22  CHI
# 4      Zach Collins   3057240               USA               10   20  POR
# ..              ...       ...               ...              ...  ...  ...
# 480      Al Horford  27734405  Dominican Rep...                3   31  BOS
# 481     Abdel Nader   1167333             Egypt               58   24  BOS
# 482  Aaron Harrison     83129               USA               62   23  DAL
# 483    Aaron Gordon   5504420               USA                4   22  ORL
# 484    Aaron Brooks   2116955               USA               26   33  MIN
#
# ...

# %% [markdown]
# **Se disponen de 485 registros con 28 variables a analizar**

# %% [markdown]
# ## Preparación de los datos

# %%
df.describe(include="all").transpose()
# Out:
#                 count unique         top freq         mean         std    min  \
# Player            485    483  Kay Felder    3          NaN         NaN    NaN
# Salary            485    NaN         NaN  NaN  6.63651e+06  7.3926e+06  46080
# NBA_Country       485     44         USA  374          NaN         NaN    NaN
# NBA_DraftNumber   485    NaN         NaN  NaN      29.4515     21.1258      1
# Age               485    NaN         NaN  NaN      26.2639      4.2723     19
# Tm                485     31         TOT   55          NaN         NaN    NaN
# G                 485    NaN         NaN  NaN       50.167     24.8749      1
# MP                485    NaN         NaN  NaN      1154.14     811.357      1
# PER               485    NaN         NaN  NaN      13.2608     8.76928  -41.1
# TS%               483    NaN         NaN  NaN     0.535387    0.112352      0
# 3PAr              483    NaN         NaN  NaN     0.337383    0.226894      0
# ...
